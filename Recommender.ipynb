# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/ramandeepkaur/.cache/kagglehub/datasets/dylanjcastillo/7k-books-with-metadata/versions/3

# %%
import pandas as pd
books = pd.read_csv(f"{path}/books.csv")

# %%
books
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 6805             Talks with Sri Nisargadatta Maharaj
# 6806                                             NaN
# 6807                                             NaN
# 6808                                             NaN
# 6809  Jeanette Winterson and the Politics of Reading
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                             Stephen R. Donaldson
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# ...                                            ...
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6806                                 Khalil Gibran
# 6807                                  Ray Bradbury
# 6808                 Georg Wilhelm Friedrich Hegel
# 6809                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                  American fiction
# 3                           Fiction
# 4                    Christian life
# ...                             ...
# 6805                     Philosophy
# 6806                      Mysticism
# 6807                   Book burning
# 6808                        History
# 6809             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=OmQaw...
# 3     http://books.google.com/books/content?id=FKo2T...
# 4     http://books.google.com/books/content?id=XhQ5X...
# ...                                                 ...
# 6805  http://books.google.com/books/content?id=Fv_JP...
# 6806  http://books.google.com/books/content?id=XcrVp...
# 6807                                                NaN
# 6808  http://books.google.com/books/content?id=Vy7Sk...
# 6809  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# ...                                                 ...             ...
# 6805  This collection of the timeless teachings of o...          1999.0
# 6806                                                NaN          1993.0
# 6807                                                NaN          2004.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
# 6809  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.97      479.0          172.0
# 3               3.93      512.0        29532.0
# 4               4.15      170.0        33684.0
# ...              ...        ...            ...
# 6805            4.51      531.0          104.0
# 6806            4.08       74.0          324.0
# 6807            3.98      186.0         5733.0
# 6808            0.00      210.0            0.0
# 6809            3.70      136.0           10.0
#
# [6810 rows x 12 columns]

# %%
print("Shape:", books.shape)   # (rows, columns)
print("\nData types & non-null counts:\n")
print(books.info())
# Out:
# Shape: (6810, 12)
#
# Data types & non-null counts:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6810 non-null   int64
#  1   isbn10          6810 non-null   object
#  2   title           6810 non-null   object
#  3   subtitle        2381 non-null   object
#  4   authors         6738 non-null   object
#  5   categories      6711 non-null   object
#  6   thumbnail       6481 non-null   object
#  7   description     6548 non-null   object
#  8   published_year  6804 non-null   float64
#  9   average_rating  6767 non-null   float64
#  10  num_pages       6767 non-null   float64
#  11  ratings_count   6767 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 638.6+ KB
# None

# %%
print("\nSummary statistics:\n")
print(books.describe())
# Out:
# Summary statistics:
#
#              isbn13  published_year  average_rating    num_pages  \
# count  6.810000e+03     6804.000000     6767.000000  6767.000000
# mean   9.780677e+12     1998.630364        3.933284   348.181026
# std    6.068911e+08       10.484257        0.331352   242.376783
# min    9.780002e+12     1853.000000        0.000000     0.000000
# 25%    9.780330e+12     1996.000000        3.770000   208.000000
# 50%    9.780553e+12     2002.000000        3.960000   304.000000
# 75%    9.780810e+12     2005.000000        4.130000   420.000000
# max    9.789042e+12     2019.000000        5.000000  3342.000000
#
#        ratings_count
# count   6.767000e+03
# mean    2.106910e+04
# std     1.376207e+05
# min     0.000000e+00
# 25%     1.590000e+02
# 50%     1.018000e+03
# 75%     5.992500e+03
# max     5.629932e+06

# %%
print("\nMissing values per column:\n")
print(books.isnull().sum())
# Out:
# Missing values per column:
#
# isbn13               0
# isbn10               0
# title                0
# subtitle          4429
# authors             72
# categories          99
# thumbnail          329
# description        262
# published_year       6
# average_rating      43
# num_pages           43
# ratings_count       43
# dtype: int64

# %%
print("\nUnique values per column:\n")
for col in books.columns:
    print(f"{col}: {books[col].nunique()} unique")
# Out:
# Unique values per column:
#
# isbn13: 6810 unique
# isbn10: 6810 unique
# title: 6398 unique
# subtitle: 2009 unique
# authors: 3780 unique
# categories: 567 unique
# thumbnail: 6481 unique
# description: 6474 unique
# published_year: 94 unique
# average_rating: 200 unique
# num_pages: 915 unique
# ratings_count: 3881 unique

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Missing values heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(
    books.isnull(), 
    cbar=False, 
    cmap = "magma"
    )
plt.title("Missing Values Heatmap", fontsize=14)
plt.xlabel("Columns")
plt.ylabel("Rows (records)")
plt.show()

# %%
import numpy as np

books["missing_description"] = np.where(books["description"].isna(), 1, 0)
books["age_of_book"] = 2025 - books["published_year"]

# %%
columns_of_interest = ["num_pages", "age_of_book", "missing_description", "average_rating"]

correlation_matrix = books[columns_of_interest].corr(method = "spearman")

sns.set_theme(style="white")
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm",
                      cbar_kws={"label": "Spearman correlation"})
heatmap.set_title("Correlation heatmap")
plt.show()

# %%
book_missing = books[~(books["description"].isna()) &
      (~books["num_pages"].isna()) &
      (~books["average_rating"].isna()) &
      (~books["published_year"].isna())
]

# %%
book_missing
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          The One Tree
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# 6808                           The Berlin Phenomenology
# 6809                          'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 6803                                             NaN
# 6804                                             NaN
# 6805             Talks with Sri Nisargadatta Maharaj
# 6808                                             NaN
# 6809  Jeanette Winterson and the Politics of Reading
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                             Stephen R. Donaldson
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# ...                                            ...
# 6803                                 Hermann Hesse
# 6804                                  Robin Sharma
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6808                 Georg Wilhelm Friedrich Hegel
# 6809                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                  American fiction
# 3                           Fiction
# 4                    Christian life
# ...                             ...
# 6803              Adventure stories
# 6804               Health & Fitness
# 6805                     Philosophy
# 6808                        History
# 6809             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=OmQaw...
# 3     http://books.google.com/books/content?id=FKo2T...
# 4     http://books.google.com/books/content?id=XhQ5X...
# ...                                                 ...
# 6803  http://books.google.com/books/content?id=rq6JP...
# 6804  http://books.google.com/books/content?id=c_7mf...
# 6805  http://books.google.com/books/content?id=Fv_JP...
# 6808  http://books.google.com/books/content?id=Vy7Sk...
# 6809  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# ...                                                 ...             ...
# 6803  This book tells the tale of a man who goes on ...          2002.0
# 6804  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 6805  This collection of the timeless teachings of o...          1999.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
# 6809  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count  missing_description  \
# 0               3.85      247.0          361.0                    0
# 1               3.83      241.0         5164.0                    0
# 2               3.97      479.0          172.0                    0
# 3               3.93      512.0        29532.0                    0
# 4               4.15      170.0        33684.0                    0
# ...              ...        ...            ...                  ...
# 6803            3.70      175.0           24.0                    0
# 6804            3.82      198.0         1568.0                    0
# 6805            4.51      531.0          104.0                    0
# 6808            0.00      210.0            0.0                    0
# 6809            3.70      136.0           10.0                    0
#
#       age_of_book
# 0            21.0
# 1            25.0
# 2            43.0
# 3            32.0
# 4            23.0
# ...           ...
# 6803         23.0
# 6804         22.0
# 6805         26.0
# 6808         44.0
# 6809         27.0
#
# [6507 rows x 14 columns]

# %%
book_missing["categories"].value_counts().reset_index().sort_values("count", ascending=False)
# Out:
#                     categories  count
# 0                      Fiction   2523
# 1             Juvenile Fiction    534
# 2    Biography & Autobiography    391
# 3                      History    258
# 4           Literary Criticism    164
# ..                         ...    ...
# 280                    Butlers      1
# 279                    Gardens      1
# 278                  Assassins      1
# 277             Married people      1
# 530    Indic fiction (English)      1
#
# [531 rows x 2 columns]

# %%
# Get counts
cat_counts = book_missing["categories"].value_counts().reset_index()
cat_counts.columns = ["category", "count"]


# Plot top 10 categories
plt.figure(figsize=(12,6))
sns.barplot(data=cat_counts[:20], x="count", y="category", palette="viridis")

plt.xlabel("Count")
plt.ylabel("Category")
plt.title("Top 10 Book Categories")
plt.show()

# %%
book_missing["words_in_description"] = book_missing["description"].str.split().str.len()
# Out:
# /var/folders/73/g21k99v96hj8xq2lzlzc80v80000gn/T/ipykernel_20191/1643189423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_missing["words_in_description"] = book_missing["description"].str.split().str.len()

# %%
book_missing
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          The One Tree
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# 6808                           The Berlin Phenomenology
# 6809                          'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 6803                                             NaN
# 6804                                             NaN
# 6805             Talks with Sri Nisargadatta Maharaj
# 6808                                             NaN
# 6809  Jeanette Winterson and the Politics of Reading
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                             Stephen R. Donaldson
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# ...                                            ...
# 6803                                 Hermann Hesse
# 6804                                  Robin Sharma
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6808                 Georg Wilhelm Friedrich Hegel
# 6809                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                  American fiction
# 3                           Fiction
# 4                    Christian life
# ...                             ...
# 6803              Adventure stories
# 6804               Health & Fitness
# 6805                     Philosophy
# 6808                        History
# 6809             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=OmQaw...
# 3     http://books.google.com/books/content?id=FKo2T...
# 4     http://books.google.com/books/content?id=XhQ5X...
# ...                                                 ...
# 6803  http://books.google.com/books/content?id=rq6JP...
# 6804  http://books.google.com/books/content?id=c_7mf...
# 6805  http://books.google.com/books/content?id=Fv_JP...
# 6808  http://books.google.com/books/content?id=Vy7Sk...
# 6809  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# ...                                                 ...             ...
# 6803  This book tells the tale of a man who goes on ...          2002.0
# 6804  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 6805  This collection of the timeless teachings of o...          1999.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
# 6809  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count  missing_description  \
# 0               3.85      247.0          361.0                    0
# 1               3.83      241.0         5164.0                    0
# 2               3.97      479.0          172.0                    0
# 3               3.93      512.0        29532.0                    0
# 4               4.15      170.0        33684.0                    0
# ...              ...        ...            ...                  ...
# 6803            3.70      175.0           24.0                    0
# 6804            3.82      198.0         1568.0                    0
# 6805            4.51      531.0          104.0                    0
# 6808            0.00      210.0            0.0                    0
# 6809            3.70      136.0           10.0                    0
#
#       age_of_book  words_in_description
# 0            21.0                   199
# 1            25.0                   205
# 2            43.0                    14
# 3            32.0                    57
# 4            23.0                    45
# ...           ...                   ...
# 6803         23.0                    63
# 6804         22.0                   117
# 6805         26.0                   174
# 6808         44.0                   245
# 6809         27.0                    20
#
# [6507 rows x 15 columns]

# %%
book_missing.loc[book_missing["words_in_description"].between(1, 4), "description"]
# Out:
# 6                                           Donation.
# 11                                     Fantasy-roman.
# 748              Includes bibliographical references.
# 770                             Bound For Oregon (PB)
# 775                                No Marketing Blurb
# 812                                No Marketing Blurb
# 857                          First published in 1813.
# 944                         Edited by Maurice Hindle.
# 953                        DEFOE/ROBINSON CRUSOE (BC)
# 954                             Edited by John Carey.
# 962                         ALLEN/GETTING THINGS DONE
# 1054                            GILBERT/EAT PRAY LOVE
# 1056    "Graham Greene centennial, 1904-2004"--Cover.
# 1060                   STEINBECK/GRAPES OF WRATH (BC)
# 1346                                   Fantasy-roman.
# 1546                                      Winter 2003
# 1610                                      Winter 1999
# 1813                             National bestseller.
# 1981                                         Romance.
# 2089                               Oprah's Book Club.
# 2372                       KANDEL/IN SEARCH OF MEMORY
# 2946                           FICTION-ROMANCE/GOTHIC
# 3064                               No Marketing Blurb
# 3364                                   Fantasy-roman.
# 3425                               A novel of Israel.
# 3435                                 Science fiction.
# 3611                                Cast ages: adult.
# 3641                           A Classic Robot novel.
# 3645                           Science fiction-roman.
# 3857         Comprehensive Teacher's Guide available.
# 3959                                   Ketubot Part I
# 4262                             Issued in container.
# 4898                                   Fantasy roman.
# 5015                                             See:
# 5090                                                ?
# 5135                              (Autobiographical).
# 5161                          A classic rediscovered.
# 5243                                                .
# 5245                                                .
# 5332                               No Marketing Blurb
# 5493                         Motion, Sound, and Heat.
# 5505                                    Eventyrroman.
# 5599                                             #48.
# 5652                 see www.BloodMoonProductions.com
# 6066                               No Marketing Blurb
# 6144                             Dominion 3rd Edition
# 6180                                  Revised edition
# 6368                                        undefined
# 6402                           Meaning of life novel.
# 6499                                           Roman.
# 6557                                 Kriminalromaner.
# 6571                   Translated by Anthony Burgess.
# 6695                               No Marketing Blurb
# 6721                                          Horror.
# 6794                             源氏物語54帖、「宮田切り絵」の真骨頂。
# Name: description, dtype: object

# %%
book_missing.loc[book_missing["words_in_description"].between(5, 14), "description"]
# Out:
# 2       Volume Two of Stephen Donaldson's acclaimed se...
# 38      Koko is Peter Straub's foray into the psycholo...
# 70      A matter of life and death - and the Throne of...
# 77                         Nonsense rhyming story. 4 yrs+
# 84      A study guide for the novel There's a Boy in t...
#                               ...
# 6715    The first comprehensive guide to addressing Na...
# 6726       Presents two complete novels from Henry James.
# 6757                          Audio Book- unabriged on CD
# 6776    Raymond Chandler meets The Exorcist. Classic n...
# 6795    Book Of Five Rings is a Kodansha International...
# Name: description, Length: 308, dtype: object

# %%
book_missing.loc[book_missing["words_in_description"].between(15, 24), "description"]
# Out:
# 10      One of Sidney Sheldon's most popular and bests...
# 32      Tells the story of three generations of Chines...
# 36      A magical and fantastic collection of early st...
# 57      A young drifter finds more than he bargained f...
# 68      A new 'The Doors of Perception' for the 21st c...
#                               ...
# 6767    Everything from the fingerprints of the gods t...
# 6782    Displays one of America's leading physicist's ...
# 6783    Basics Illustration 01: Thinking Visually expl...
# 6789    Provides an introduction to the American artis...
# 6809    This is a jubilant and rewarding collection of...
# Name: description, Length: 947, dtype: object

# %%
book_missing_25_words = book_missing[book_missing["words_in_description"] >= 25]

# %%
book_missing_25_words
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# 5     9780006280934  0006280935
# ...             ...         ...
# 6802  9788172235222  8172235224
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 3                                        Rage of angels
# 4                                        The Four Loves
# 5                                   The Problem of Pain
# ...                                                 ...
# 6802                                  Mistaken Identity
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# 6808                           The Berlin Phenomenology
#
#                                  subtitle  \
# 0                                     NaN
# 1                                 A Novel
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# ...                                   ...
# 6802                                  NaN
# 6803                                  NaN
# 6804                                  NaN
# 6805  Talks with Sri Nisargadatta Maharaj
# 6808                                  NaN
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# 5                              Clive Staples Lewis
# ...                                            ...
# 6802                              Nayantara Sahgal
# 6803                                 Hermann Hesse
# 6804                                  Robin Sharma
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6808                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 3                           Fiction
# 4                    Christian life
# 5                    Christian life
# ...                             ...
# 6802        Indic fiction (English)
# 6803              Adventure stories
# 6804               Health & Fitness
# 6805                     Philosophy
# 6808                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 3     http://books.google.com/books/content?id=FKo2T...
# 4     http://books.google.com/books/content?id=XhQ5X...
# 5     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 6802  http://books.google.com/books/content?id=q-tKP...
# 6803  http://books.google.com/books/content?id=rq6JP...
# 6804  http://books.google.com/books/content?id=c_7mf...
# 6805  http://books.google.com/books/content?id=Fv_JP...
# 6808  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# 5     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 6802  On A Train Journey Home To North India After L...          2003.0
# 6803  This book tells the tale of a man who goes on ...          2002.0
# 6804  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 6805  This collection of the timeless teachings of o...          1999.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  missing_description  \
# 0               3.85      247.0          361.0                    0
# 1               3.83      241.0         5164.0                    0
# 3               3.93      512.0        29532.0                    0
# 4               4.15      170.0        33684.0                    0
# 5               4.09      176.0        37569.0                    0
# ...              ...        ...            ...                  ...
# 6802            2.93      324.0            0.0                    0
# 6803            3.70      175.0           24.0                    0
# 6804            3.82      198.0         1568.0                    0
# 6805            4.51      531.0          104.0                    0
# 6808            0.00      210.0            0.0                    0
#
#       age_of_book  words_in_description
# 0            21.0                   199
# 1            25.0                   205
# 3            32.0                    57
# 4            23.0                    45
# 5            23.0                    75
# ...           ...                   ...
# 6802         22.0                   288
# 6803         23.0                    63
# 6804         22.0                   117
# 6805         26.0                   174
# 6808         44.0                   245
#
# [5197 rows x 15 columns]

# %%
pip install langchain-community langchain-text-splitters langchain-openai langchain-chroma
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: langchain-community in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (0.3.29)
# Requirement already satisfied: langchain-text-splitters in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (0.3.9)
# Requirement already satisfied: langchain-openai in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (0.3.32)
# Requirement already satisfied: langchain-chroma in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (0.2.5)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (0.3.75)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: requests<3,>=2.32.5 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (6.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (3.9.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (0.4.20)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain-community) (2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain-community) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain-community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain-community) (2025.8.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<2.0.0,>=1.99.9 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-openai) (1.102.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-openai) (0.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (4.65.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.99.9->langchain-openai) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.99.9->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.99.9->langchain-openai) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.5.5)
# Requirement already satisfied: chromadb>=1.0.9 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langchain-chroma) (1.0.20)
# Requirement already satisfied: build>=1.0.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.35.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.36.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.21.4)
# Requirement already satisfied: pypika>=0.48.9 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (5.12.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.16.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (3.11.3)
# Requirement already satisfied: rich>=10.11.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.25.1)
# Requirement already satisfied: six>=1.5 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.9->langchain-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.9->langchain-chroma) (2.8.2)
# Requirement already satisfied: backoff>=1.10.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.9->langchain-chroma) (2.2.1)
# Requirement already satisfied: pyproject_hooks in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma) (2.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.27.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.5.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (0.24.0)
# Requirement already satisfied: coloredlogs in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (23.5.26)
# Requirement already satisfied: protobuf in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (6.32.0)
# Requirement already satisfied: sympy in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.13.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (6.6.0)
# Requirement already satisfied: zipp>=0.5 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (3.15.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.9->langchain-chroma) (0.57b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (0.34.4)
# Requirement already satisfied: filelock in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (2023.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (1.1.8)
# Requirement already satisfied: click>=8.0.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (11.0.3)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
pip install dotenv
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: dotenv in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from dotenv) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
openai_key = os.getenv("OPENAI_API_KEY")
huggingface_key = os.getenv("HUGGINGFACE_API_TOKEN")

# %%
book_missing_25_words["title_and_subtitle"] = (
    np.where(book_missing_25_words["subtitle"].isna(), book_missing_25_words["title"],
             book_missing_25_words[["title", "subtitle"]].astype(str).agg(": ".join, axis=1))
)
# Out:
# /var/folders/73/g21k99v96hj8xq2lzlzc80v80000gn/T/ipykernel_20191/950283815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_missing_25_words["title_and_subtitle"] = (

# %%
book_missing_25_words
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# 5     9780006280934  0006280935
# ...             ...         ...
# 6802  9788172235222  8172235224
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 3                                        Rage of angels
# 4                                        The Four Loves
# 5                                   The Problem of Pain
# ...                                                 ...
# 6802                                  Mistaken Identity
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# 6808                           The Berlin Phenomenology
#
#                                  subtitle  \
# 0                                     NaN
# 1                                 A Novel
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# ...                                   ...
# 6802                                  NaN
# 6803                                  NaN
# 6804                                  NaN
# 6805  Talks with Sri Nisargadatta Maharaj
# 6808                                  NaN
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# 5                              Clive Staples Lewis
# ...                                            ...
# 6802                              Nayantara Sahgal
# 6803                                 Hermann Hesse
# 6804                                  Robin Sharma
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6808                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 3                           Fiction
# 4                    Christian life
# 5                    Christian life
# ...                             ...
# 6802        Indic fiction (English)
# 6803              Adventure stories
# 6804               Health & Fitness
# 6805                     Philosophy
# 6808                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 3     http://books.google.com/books/content?id=FKo2T...
# 4     http://books.google.com/books/content?id=XhQ5X...
# 5     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 6802  http://books.google.com/books/content?id=q-tKP...
# 6803  http://books.google.com/books/content?id=rq6JP...
# 6804  http://books.google.com/books/content?id=c_7mf...
# 6805  http://books.google.com/books/content?id=Fv_JP...
# 6808  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# 5     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 6802  On A Train Journey Home To North India After L...          2003.0
# 6803  This book tells the tale of a man who goes on ...          2002.0
# 6804  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 6805  This collection of the timeless teachings of o...          1999.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  missing_description  \
# 0               3.85      247.0          361.0                    0
# 1               3.83      241.0         5164.0                    0
# 3               3.93      512.0        29532.0                    0
# 4               4.15      170.0        33684.0                    0
# 5               4.09      176.0        37569.0                    0
# ...              ...        ...            ...                  ...
# 6802            2.93      324.0            0.0                    0
# 6803            3.70      175.0           24.0                    0
# 6804            3.82      198.0         1568.0                    0
# 6805            4.51      531.0          104.0                    0
# 6808            0.00      210.0            0.0                    0
#
#       age_of_book  words_in_description  \
# 0            21.0                   199
# 1            25.0                   205
# 3            32.0                    57
# 4            23.0                    45
# 5            23.0                    75
# ...           ...                   ...
# 6802         22.0                   288
# 6803         23.0                    63
# 6804         22.0                   117
# 6805         26.0                   174
# 6808         44.0                   245
#
#                                      title_and_subtitle
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 3                                        Rage of angels
# 4                                        The Four Loves
# 5                                   The Problem of Pain
# ...                                                 ...
# 6802                                  Mistaken Identity
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805     I Am that: Talks with Sri Nisargadatta Maharaj
# 6808                           The Berlin Phenomenology
#
# [5197 rows x 16 columns]

# %%
book_missing_25_words["tagged_description"] = book_missing_25_words[["isbn13", "description"]].astype(str).agg(" ".join, axis=1)
# Out:
# /var/folders/73/g21k99v96hj8xq2lzlzc80v80000gn/T/ipykernel_20191/2295903696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_missing_25_words["tagged_description"] = book_missing_25_words[["isbn13", "description"]].astype(str).agg(" ".join, axis=1)

# %%
(
    book_missing_25_words
    .drop(["subtitle", "missing_description", "age_of_book", "words_in_description"], axis=1)
    .to_csv("books_cleaned.csv", index = False)
)

# %%
import pandas as pd

books = pd.read_csv("books_cleaned.csv")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description
# 0     9780002005883 A NOVEL THAT READERS and critics...
# 1     9780002261982 A new 'Christie for Christmas' -...
# 2     9780006178736 A memorable, mesmerizing heroine...
# 3     9780006280897 Lewis' work on the nature of lov...
# 4     9780006280934 "In The Problem of Pain, C.S. Le...
# ...                                                 ...
# 5192  9788172235222 On A Train Journey Home To North...
# 5193  9788173031014 This book tells the tale of a ma...
# 5194  9788179921623 Wisdom to Create a Life of Passi...
# 5195  9788185300535 This collection of the timeless ...
# 5196  9789027712059 Since the three volume edition o...
#
# [5197 rows x 13 columns]

# %%
books["tagged_description"].to_csv("tagged_description.txt",
                                   sep = "\n",
                                   index = False,
                                   header = False)

# %%
raw_documents = TextLoader("tagged_description.txt").load()
text_splitter = CharacterTextSplitter(chunk_size=2000, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 2010, which is longer than the specified 2000
# Created a chunk of size 2012, which is longer than the specified 2000
# Created a chunk of size 2834, which is longer than the specified 2000
# Created a chunk of size 2510, which is longer than the specified 2000
# Created a chunk of size 2008, which is longer than the specified 2000
# Created a chunk of size 2285, which is longer than the specified 2000
# Created a chunk of size 2616, which is longer than the specified 2000
# Created a chunk of size 2030, which is longer than the specified 2000
# Created a chunk of size 2762, which is longer than the specified 2000
# Created a chunk of size 2005, which is longer than the specified 2000
# Created a chunk of size 2141, which is longer than the specified 2000
# Created a chunk of size 2209, which is longer than the specified 2000
# Created a chunk of size 2877, which is longer than the specified 2000
# Created a chunk of size 2398, which is longer than the specified 2000
# Created a chunk of size 2120, which is longer than the specified 2000
# Created a chunk of size 2181, which is longer than the specified 2000
# Created a chunk of size 2171, which is longer than the specified 2000
# Created a chunk of size 2723, which is longer than the specified 2000
# Created a chunk of size 2456, which is longer than the specified 2000
# Created a chunk of size 2450, which is longer than the specified 2000
# Created a chunk of size 3168, which is longer than the specified 2000
# Created a chunk of size 2034, which is longer than the specified 2000
# Created a chunk of size 2031, which is longer than the specified 2000
# Created a chunk of size 2940, which is longer than the specified 2000
# Created a chunk of size 2146, which is longer than the specified 2000
# Created a chunk of size 2490, which is longer than the specified 2000
# Created a chunk of size 3784, which is longer than the specified 2000
# Created a chunk of size 2702, which is longer than the specified 2000
# Created a chunk of size 5836, which is longer than the specified 2000
# Created a chunk of size 2075, which is longer than the specified 2000
# Created a chunk of size 2002, which is longer than the specified 2000
# Created a chunk of size 2082, which is longer than the specified 2000
# Created a chunk of size 2297, which is longer than the specified 2000
# Created a chunk of size 2071, which is longer than the specified 2000
# Created a chunk of size 2021, which is longer than the specified 2000
# Created a chunk of size 2022, which is longer than the specified 2000
# Created a chunk of size 2372, which is longer than the specified 2000
# Created a chunk of size 2351, which is longer than the specified 2000
# Created a chunk of size 2350, which is longer than the specified 2000
# Created a chunk of size 2334, which is longer than the specified 2000
# Created a chunk of size 2946, which is longer than the specified 2000
# Created a chunk of size 3243, which is longer than the specified 2000
# Created a chunk of size 2780, which is longer than the specified 2000
# Created a chunk of size 2085, which is longer than the specified 2000
# Created a chunk of size 2018, which is longer than the specified 2000
# Created a chunk of size 2713, which is longer than the specified 2000
# Created a chunk of size 2278, which is longer than the specified 2000
# Created a chunk of size 2051, which is longer than the specified 2000
# Created a chunk of size 2014, which is longer than the specified 2000
# Created a chunk of size 2067, which is longer than the specified 2000
# Created a chunk of size 2855, which is longer than the specified 2000
# Created a chunk of size 2869, which is longer than the specified 2000
# Created a chunk of size 2347, which is longer than the specified 2000
# Created a chunk of size 2451, which is longer than the specified 2000
# Created a chunk of size 2149, which is longer than the specified 2000
# Created a chunk of size 2742, which is longer than the specified 2000
# Created a chunk of size 3938, which is longer than the specified 2000

# %%
documents[0]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content='9780002005883 A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.')

# %%
pip install sentence-transformers
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: sentence-transformers in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (5.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (4.55.4)
# Requirement already satisfied: tqdm in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: filelock in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.12.4)
# Requirement already satisfied: numpy>=1.17 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2023.5.5)
# Requirement already satisfied: requests in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.8)
# Requirement already satisfied: networkx in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ramandeepkaur/miniforge3/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
db_books = Chroma.from_documents(documents, embedding=embeddings)

# %%
query = "A book to teach children about nature"
docs = db_books.similarity_search(query, k = 10)
docs
# Out:
# [Document(id='f60d1355-5051-409b-8234-af8ae4f13f62', metadata={'source': 'tagged_description.txt'}, page_content='"9780618471164 The Earth and Its Peoples Brief Edition is a compact presentation of world history with a comparative approach and a global, balanced perspective. The themes of ""Environment and Technology"" and ""Diversity and Dominance"" unite the regions of the world. The Earth and Its Peoples Brief Edition offers a high level of scholarship with a supportive, student-friendly format."\n9780618477906 On Christmas eve, a young boy joins some other children on a magical train ride to the North Pole, in an adaptation of the new movie being released this holiday season. Original.\n9780618477944 A memoir done in the form of a graphic novel by a cult favorite comic artist offers a darkly funny family portrait that details her relationship with her father--a funeral home director, high school English teacher, and closeted homosexual.\n"9780618479030 The best-selling books of Andrew Weil, ""the guru of alternative medicine,"" (San Francisco Examiner) offer a comprehensive blend of traditional and alternative methods that help to achieve better health in the modern world. Natural Health, Natural Medicine is a comprehensive resource for everything you need to know to maintain optimum health and treat common ailments. This landmark book incorporates Dr. Weil’s theories of preventive health maintenance and alternative healing into one extremely useful and readable reference, featuring general diet and nutrition information as well as simple recipes, answers to readers’ most pressing questions, a catalogue of home remedies, invaluable resources, and hundreds of practical tips. This edition includes up-to-the-minute scientific findings and has been expanded to provide trustworthy advice about low-carb diets, hormone replacement therapy, Alzheimer’s, attention deficit disorder, reflux disease, autism, type 2 diabetes, erectile dysfunction, the flu, and much more."'),
#  Document(id='857aa19b-e28e-4324-b40e-2ad2245a4b5e', metadata={'source': 'tagged_description.txt'}, page_content="9780007151240 It should be the most natural thing in the world. But in Tony Parsons' latest bestseller, three couples discover that Mother Nature can be one hell of a bitch.\n9780007151677 Gipsy S Acre Was A Truly Beautiful Upland Site With Views Out To Sea And In Michael Rogers It Stirred A Child-Like Fantasy. There, Among The Dark Fir Trees, He Planned To Build A House, Find A Wonderful Girl And Live Happily Ever After, Yet, As He Left The Village, A Shadow Of Menace Hung Over The Land. For This Was The Place Where Accidents Happened. Perhaps Michael Should Have Heeded The Locals Warnings: There S No Luck For Them As Meddles With Gipsy S Acre .\n9780007153589 'The Harper's Essay' is reprinted in this volume alongside personal essays and painstaking, often funny reportage. Although his subjects range widely, each piece wrestles with the erosion of civic life and private dignity, and the hidden persistence of loneliness in postmodern America.\n9780007154845 A mysterious stranger appears at a New Year's Eve party, becoming the enigmatic sleuthing sidekick to the snobbish Mr Satterthwaite... So far, it had been a typical New Year's Eve house party. But Mr Satterthwaite - a keen observer of human nature - sensed that the real drama of the evening was yet to unfold. So it proved when a mysterious stranger arrived after midnight. Who was this Mr Quin? And why did his presence have such a pronounced effect on Eleanor Portal, the woman with the dyed-black hair?")]

# %%
isbn = docs[0].page_content.split()[0].strip().strip('"').strip("'")
isbn
# Out:
# '9780618471164'

# %%
books[books["isbn13"] == int(docs[0].page_content.split()[0].strip().strip('"').strip("'"))]
# Out:
#              isbn13      isbn10                       title  \
# 2922  9780618471164  0618471162  Since 1500, Chapters 15-30
#
#                  authors categories  \
# 2922  Richard W. Bulliet    Science
#
#                                               thumbnail  \
# 2922  http://books.google.com/books/content?id=DS0C7...
#
#                                             description  published_year  \
# 2922  The Earth and Its Peoples Brief Edition is a c...          2005.0
#
#       average_rating  num_pages  ratings_count  \
# 2922             4.0       34.0            8.0
#
#                                      title_and_subtitle  \
# 2922  Since 1500, Chapters 15-30: The Earth and Its ...
#
#                                      tagged_description
# 2922  9780618471164 The Earth and Its Peoples Brief ...

# %%
def retrieve_semantic_recommendations(
        query: str,
        top_k: int = 10,
) -> pd.DataFrame:
    recs = db_books.similarity_search(query, k = 50)

    books_list = []

    for i in range(0, len(recs)):
        books_list += [int(recs[i].page_content.strip('"').strip("' ").split()[0])]

    return books[books["isbn13"].isin(books_list)]

# %%
retrieve_semantic_recommendations("A book to teach children about nature")
# Out:
#              isbn13      isbn10  \
# 59    9780007151240  0007151241
# 270   9780060885373  0060885378
# 391   9780061205699  0061205699
# 404   9780064402453  0064402452
# 407   9780064404419  0064404412
# 411   9780064405478  0064405478
# 415   9780064406307  006440630X
# 428   9780064434942  006443494X
# 432   9780064440950  0064440958
# 435   9780064462341  006446234X
# 442   9780067575208  006757520X
# 1733  9780375760136  037576013X
# 1940  9780393927207  0393927202
# 2569  9780517168950  0517168952
# 2922  9780618471164  0618471162
# 3000  9780671631987  0671631985
# 3579  9780762427321  0762427329
# 3748  9780786808373  0786808373
# 4194  9780881507195  0881507199
# 4215  9780887511127  0887511120
# 4262  9780940450738  0940450739
# 4293  9780974514055  0974514055
# 4808  9781586853334  1586853333
# 4899  9781593854461  1593854463
# 59                                       The Family Way
# 270                       Little House in the Big Woods
# 391           To Kill a Mockingbird (slipcased edition)
# 404                          Racso and the Rats of NIMH
# 407                                  The Rainbow People
# 411                                  Betsy Was a Junior
# 415                     The Midwife's Apprentice (rpkg)
# 428                             A Little House Birthday
# 432                                             Chester
# 435     Pioneer Girl: The Story of Laura Ingalls Wilder
# 442                                 The Sense of Wonder
# 1733                                     Daniel Deronda
# 1940         The Norton Anthology of English Literature
# 2569                                       The Crossing
# 2922  Since 1500, Chapters 15-30: The Earth and Its ...
# 3000       Teach Your Child to Read in 100 Easy Lessons
# 3579  The Illustrated on the Shoulders of Giants: Th...
# 3748                               Baby Einstein: Birds
# 4194  King Arthur Flour Whole Grain Baking: Deliciou...
# 4215  Teaching the World's Children: ESL for Ages Th...
# 4262  Collected tales, sketches, speeches, and essay...
# 4293  Programming Ruby: The Pragmatic Programmers' G...
# 4808                          The Big Book of Boy Stuff
# 4899  Teaching Reading Comprehension to Students wit...
# 5100  Teach Them Diligently: How to Use the Scriptur...
#
#                                      tagged_description
# 59    9780007151240 It should be the most natural th...
# 270   9780060885373 A year in the life of two young ...
# 391   9780061205699 At the age of eight, Scout Finch...
# 404   9780064402453 ‘Racso, a brash and boastful lit...
# 407   9780064404419 "Culled from 69 stories collecte...
# 411   9780064405478 A small town shortly after the t...
# 415   9780064406307 'Like Cushman's 1995 Newbery Hon...
# 428   9780064434942 Join the Ingalls family as they ...
# 432   9780064440950 Chester, a wild horse who wants ...
# 435   9780064462341 The pioneer spirit lives on... R...
# 442   9780067575208 First published more than three ...
# 1733  9780375760136 Deronda, a high-minded young man...
# 1940  9780393927207 Firmly grounded by the hallmark ...
# 2569  9780517168950 Following All the Pretty Horses ...
# 2922  9780618471164 The Earth and Its Peoples Brief ...
# 3000  9780671631987 With more than half a million co...
# 3579  9780762427321 Hawking's revolutionary look at ...
# 3748  9780786808373 Introducing your baby to birds, ...
# 4194  9780881507195 A guide to whole grain baking ex...
# 4215  9780887511127 The language young children use ...
# 4262  9780940450738 This with its companion volume i...
# 4293  9780974514055 A tutorial and reference to the ...
# 4808  9781586853334 There's this boy. Let's say he's...
# 4899  9781593854461 A ChoiceOutstanding Academic Tit...
# 5100  9781889032207 The bookshelves in your home no ...

# %%
books = pd.read_csv("books_cleaned.csv")

# %%
books["categories"].value_counts().reset_index()
# Out:
#                     categories  count
# 0                      Fiction   2111
# 1             Juvenile Fiction    390
# 2    Biography & Autobiography    311
# 3                      History    207
# 4           Literary Criticism    124
# ..                         ...    ...
# 474               Conspiracies      1
# 475       Brothers and sisters      1
# 476             Rock musicians      1
# 477             Community life      1
# 478    Indic fiction (English)      1
#
# [479 rows x 2 columns]

# %%
books["categories"].value_counts().reset_index().query("count > 50")
# Out:
#                    categories  count
# 0                     Fiction   2111
# 1            Juvenile Fiction    390
# 2   Biography & Autobiography    311
# 3                     History    207
# 4          Literary Criticism    124
# 5                  Philosophy    117
# 6                    Religion    117
# 7     Comics & Graphic Novels    116
# 8                       Drama     86
# 9         Juvenile Nonfiction     57
# 10                    Science     56
# 11                     Poetry     51

# %%
category_mapping = {'Fiction' : "Fiction",
 'Juvenile Fiction': "Children's Fiction",
 'Biography & Autobiography': "Nonfiction",
 'History': "Nonfiction",
 'Literary Criticism': "Nonfiction",
 'Philosophy': "Nonfiction",
 'Religion': "Nonfiction",
 'Comics & Graphic Novels': "Fiction",
 'Drama': "Fiction",
 'Juvenile Nonfiction': "Children's Nonfiction",
 'Science': "Nonfiction",
 'Poetry': "Fiction"}

books["simple_categories"] = books["categories"].map(category_mapping)

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...               NaN
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...               NaN
# 4     9780006280934 "In The Problem of Pain, C.S. Le...               NaN
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...               NaN
# 5193  9788173031014 This book tells the tale of a ma...               NaN
# 5194  9788179921623 Wisdom to Create a Life of Passi...               NaN
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
# [5197 rows x 14 columns]

# %%
books[~(books["simple_categories"].isna())]
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 2     9780006178736  0006178731             Rage of angels
# 8     9780006482079  0006482074        Warhost of Vastmark
# 30    9780006646006  000664600X         Ocean Star Express
# 46    9780007121014  0007121016         Taken at the Flood
# ...             ...         ...                        ...
# 5178  9781933648279  1933648279  Night Has a Thousand Eyes
# 5188  9784770028969  4770028962         Coin Locker Babies
# 5189  9788122200850  8122200850           Cry, the Peacock
# 5195  9788185300535  8185300534                  I Am that
# 5196  9789027712059  9027712050   The Berlin Phenomenology
#
#                                            authors        categories  \
# 0                               Marilynne Robinson           Fiction
# 2                                   Sidney Sheldon           Fiction
# 8                                      Janny Wurts           Fiction
# 30                        Mark Haddon;Peter Sutton  Juvenile Fiction
# 46                                 Agatha Christie           Fiction
# ...                                            ...               ...
# 5178                              Cornell Woolrich           Fiction
# 5188                                           村上龍           Fiction
# 5189                                   Anita Desai           Fiction
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit        Philosophy
# 5196                 Georg Wilhelm Friedrich Hegel           History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 8     http://books.google.com/books/content?id=uOL0f...
# 30    http://books.google.com/books/content?id=I2QZA...
# 46    http://books.google.com/books/content?id=3gWlx...
# ...                                                 ...
# 5178  http://books.google.com/books/content?id=3Gk6s...
# 5188  http://books.google.com/books/content?id=87DJw...
# 5189  http://books.google.com/books/content?id=_QKwV...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 8     Tricked once more by his wily half-brother, Ly...          1995.0
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 46    A Few Weeks After Marrying An Attractive Young...          2002.0
# ...                                                 ...             ...
# 5178  "Cornell Woolrich's novels define the essence ...          2007.0
# 5188  Rescued from the lockers in which they were le...          2002.0
# 5189  This book is the story of a young girl obsesse...          1980.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 2               3.93      512.0        29532.0
# 8               4.03      522.0         2966.0
# 30              3.50       32.0            1.0
# 46              3.71      352.0         8852.0
# ...              ...        ...            ...
# 5178            3.77      344.0          680.0
# 5188            3.75      393.0         5560.0
# 5189            3.22      218.0          134.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                   title_and_subtitle  \
# 0                                             Gilead
# 2                                     Rage of angels
# 8                                Warhost of Vastmark
# 30                                Ocean Star Express
# 46                                Taken at the Flood
# ...                                              ...
# 5178                       Night Has a Thousand Eyes
# 5188                              Coin Locker Babies
# 5189                                Cry, the Peacock
# 5195  I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                        The Berlin Phenomenology
#
#                                      tagged_description   simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...             Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...             Fiction
# 8     9780006482079 Tricked once more by his wily ha...             Fiction
# 30    9780006646006 Joe and his parents are enjoying...  Children's Fiction
# 46    9780007121014 A Few Weeks After Marrying An At...             Fiction
# ...                                                 ...                 ...
# 5178  9781933648279 "Cornell Woolrich's novels defin...             Fiction
# 5188  9784770028969 Rescued from the lockers in whic...             Fiction
# 5189  9788122200850 This book is the story of a youn...             Fiction
# 5195  9788185300535 This collection of the timeless ...          Nonfiction
# 5196  9789027712059 Since the three volume edition o...          Nonfiction
#
# [3743 rows x 14 columns]

# %%
from transformers import pipeline

fiction_categories = ["Fiction", "Nonfiction"]

pipe = pipeline("zero-shot-classification",
                model="facebook/bart-large-mnli",
                device="mps")
# Out:
# Device set to use mps

# %%
sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]

# %%
pipe(sequence, fiction_categories)
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#  'labels': ['Fiction', 'Nonfiction'],
#  'scores': [0.8438272476196289, 0.15617279708385468]}

# %%
import numpy as np

max_index = np.argmax(pipe(sequence, fiction_categories)["scores"])
max_label = pipe(sequence, fiction_categories)["labels"][max_index]
max_label
# Out:
# 'Fiction'

# %%
def generate_predictions(sequence, categories):
    predictions = pipe(sequence, categories)
    max_index = np.argmax(predictions["scores"])
    max_label = predictions["labels"][max_index]
    return max_label

# %%
from tqdm import tqdm

actual_cats = []
predicted_cats = []

for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Fiction"]
# Out:
# 100%|█████████████████████████████████████████| 300/300 [00:59<00:00,  5.03it/s]

# %%
for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Nonfiction"]
# Out:
# 100%|█████████████████████████████████████████| 300/300 [00:53<00:00,  5.60it/s]

# %%
predictions_df = pd.DataFrame({"actual_categories": actual_cats, "predicted_categories": predicted_cats})

# %%
predictions_df
# Out:
#     actual_categories predicted_categories
# 0             Fiction              Fiction
# 1             Fiction              Fiction
# 2             Fiction              Fiction
# 3             Fiction           Nonfiction
# 4             Fiction              Fiction
# ..                ...                  ...
# 295           Fiction           Nonfiction
# 296           Fiction              Fiction
# 297           Fiction           Nonfiction
# 298           Fiction              Fiction
# 299           Fiction              Fiction
#
# [300 rows x 2 columns]

# %%
predictions_df["correct_prediction"] = (
    np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0)
)

# %%
predictions_df["correct_prediction"].sum() / len(predictions_df)
# Out:
# 0.68

# %%
isbns = []
predicted_cats = []

missing_cats = books.loc[books["simple_categories"].isna(), ["isbn13", "description"]].reset_index(drop=True)

# %%
for i in tqdm(range(0, len(missing_cats))):
    sequence = missing_cats["description"][i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    isbns += [missing_cats["isbn13"][i]]
# Out:
# 100%|███████████████████████████████████████| 1454/1454 [04:15<00:00,  5.68it/s]

# %%
missing_predicted_df = pd.DataFrame({"isbn13": isbns, "predicted_categories": predicted_cats})

# %%
missing_predicted_df
# Out:
#              isbn13 predicted_categories
# 0     9780002261982              Fiction
# 1     9780006280897           Nonfiction
# 2     9780006280934           Nonfiction
# 3     9780006380832           Nonfiction
# 4     9780006470229              Fiction
# ...             ...                  ...
# 1449  9788125026600           Nonfiction
# 1450  9788171565641              Fiction
# 1451  9788172235222              Fiction
# 1452  9788173031014           Nonfiction
# 1453  9788179921623              Fiction
#
# [1454 rows x 2 columns]

# %%
books = pd.merge(books, missing_predicted_df, on="isbn13", how="left")
books["simple_categories"] = np.where(books["simple_categories"].isna(), books["predicted_categories"], books["simple_categories"])
books = books.drop(columns = ["predicted_categories"])

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
# [5197 rows x 14 columns]

# %%
books[books["categories"].str.lower().isin([
    "romance",
    "science fiction",
    "scifi",
    "fantasy",
    "horror",
    "mystery",
    "thriller",
    "comedy",
    "crime",
    "historical"
])]
# Out:
#              isbn13      isbn10                                     title  \
# 24    9780006513087  0006513085                                   Gravity
# 475   9780099410355  0099410354                                   Traitor
# 478   9780099422341  0099422344                            Yeats is Dead!
# 491   9780099446729  0099446723                            Blackwood Farm
# 1090  9780261102422  0261102427                          The Silmarillion
# 1435  9780340837955  0340837950                Stranger in a Strange Land
# 1439  9780345251220  0345251229                      Visions from Nowhere
# 2845  9780575075597  0575075597                                    Replay
# 2860  9780590254762  0590254766      The lion, the witch and the wardrobe
# 3288  9780739423851  0739423851                           Wizard's Castle
# 3289  9780739439708  0739439707                              Time Quartet
# 3563  9780760728505  076072850X              20,000 Leagues Under the Sea
# 4483  9781416502043  1416502041  The Voyage of the Jerle Shannara Trilogy
# 4979  9781841494081  1841494089            The Darkness that Comes Before
# 5040  9781857231359  185723135X                            Use of Weapons
# 5057  9781857989342  1857989341                       The Gods Themselves
#
#                         authors       categories  \
# 24               Tess Gerritsen  Science fiction
# 475     Matthew Woodring Stover  Science fiction
# 478             Joseph O'Connor           Comedy
# 491                   Anne Rice           Horror
# 1090  John Ronald Reuel Tolkien          Fantasy
# 1435         Robert A. Heinlein  Science fiction
# 1439              William Arrow  Science fiction
# 2845               Ken Grimwood          Fantasy
# 2860        Clive Staples Lewis          Fantasy
# 3288          Diana Wynne Jones          Fantasy
# 3289          Madeleine L'Engle  Science fiction
# 3563                Jules Verne  Science fiction
# 4483               Terry Brooks          Fantasy
# 4979            R. Scott Bakker          Fantasy
# 5040                 Iain Banks  Science fiction
# 5057               Isaac Asimov  Science fiction
#
#                                               thumbnail  \
# 24    http://books.google.com/books/content?id=KI66c...
# 475   http://books.google.com/books/content?id=VbICO...
# 1439  9780345251220 The first novel in the series, "...           Fiction
# 2845  9780575075597 At forty-three Jeff Winston is t...           Fiction
# 2860  9780590254762 Four English school children ent...        Nonfiction
# 3288  9780739423851 Howl's moving castle - Eldest of...           Fiction
# 3289  9780739439708 Blending magic with quantum phys...           Fiction
# 3563  9780760728505 Retells the adventures of a Fren...           Fiction
# 4483  9781416502043 When the body of a half-drowned ...           Fiction
# 4979  9781841494081 A score of centuries has passed ...        Nonfiction
# 5040  9781857231359 The man known as Cheradenine Zak...        Nonfiction
# 5057  9781857989342 In the year 2100, mankind on Ear...           Fiction

# %%
books.to_csv("books_with_categories.csv", index=False)

# %%
from transformers import pipeline
classifier = pipeline("text-classification",
                      model="j-hartmann/emotion-english-distilroberta-base",
                      top_k = None,
                      device = "mps")
classifier("I love this!")
# Out:
# Device set to use mps
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.00852868054062128},
#   {'label': 'neutral', 'score': 0.00576459476724267},
#   {'label': 'anger', 'score': 0.004419783595949411},
#   {'label': 'sadness', 'score': 0.002092391485348344},
#   {'label': 'disgust', 'score': 0.001611992483958602},
#   {'label': 'fear', 'score': 0.00041385198710486293}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548422574996948},
#   {'label': 'neutral', 'score': 0.16985155642032623},
#   {'label': 'sadness', 'score': 0.11640843003988266},
#   {'label': 'surprise', 'score': 0.020700642839074135},
#   {'label': 'disgust', 'score': 0.019100701436400414},
#   {'label': 'joy', 'score': 0.015161211602389812},
#   {'label': 'anger', 'score': 0.003935141488909721}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296021580696106},
#   {'label': 'neutral', 'score': 0.14038625359535217},
#   {'label': 'fear', 'score': 0.06816215068101883},
#   {'label': 'joy', 'score': 0.0479423962533474},
#   {'label': 'anger', 'score': 0.009156353771686554},
#   {'label': 'disgust', 'score': 0.0026284793857485056},
#   {'label': 'sadness', 'score': 0.0021221640054136515}],
#  [{'label': 'neutral', 'score': 0.44937190413475037},
#   {'label': 'disgust', 'score': 0.2735902965068817},
#   {'label': 'joy', 'score': 0.1090828999876976},
#   {'label': 'sadness', 'score': 0.09362740814685822},
#   {'label': 'anger', 'score': 0.04047819972038269},
#   {'label': 'surprise', 'score': 0.02697022259235382},
#   {'label': 'fear', 'score': 0.00687906239181757}],
#  [{'label': 'neutral', 'score': 0.6462160348892212},
#   {'label': 'sadness', 'score': 0.24273350834846497},
#   {'label': 'disgust', 'score': 0.043422576040029526},
#   {'label': 'surprise', 'score': 0.02830047346651554},
#   {'label': 'joy', 'score': 0.014211434870958328},
#   {'label': 'fear', 'score': 0.01408408209681511},
#   {'label': 'anger', 'score': 0.011031867004930973}],
#  [{'label': 'fear', 'score': 0.9281686544418335},
#   {'label': 'anger', 'score': 0.032190557569265366},
#   {'label': 'neutral', 'score': 0.012808652594685555},
#   {'label': 'sadness', 'score': 0.00875683594495058},
#   {'label': 'surprise', 'score': 0.008597896434366703},
#   {'label': 'disgust', 'score': 0.008431782014667988},
#   {'label': 'joy', 'score': 0.0010455816518515348}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104156918823719},
#   {'label': 'disgust', 'score': 0.006480598822236061},
#   {'label': 'fear', 'score': 0.005394003354012966},
#   {'label': 'surprise', 'score': 0.0022869419772177935},
#   {'label': 'anger', 'score': 0.0018428885377943516},
#   {'label': 'joy', 'score': 0.0017338788602501154}],
#  [{'label': 'joy', 'score': 0.9327981472015381},
#   {'label': 'disgust', 'score': 0.037716999650001526},
#   {'label': 'neutral', 'score': 0.015891842544078827},
#   {'label': 'sadness', 'score': 0.006444488186389208},
#   {'label': 'anger', 'score': 0.005024961195886135},
#   {'label': 'surprise', 'score': 0.00158120587002486},
#   {'label': 'fear', 'score': 0.0005423062248155475}],
#  [{'label': 'joy', 'score': 0.6528695225715637},
#   {'label': 'neutral', 'score': 0.25427553057670593},
#   {'label': 'surprise', 'score': 0.06808329373598099},
#   {'label': 'sadness', 'score': 0.009909017942845821},
#   {'label': 'disgust', 'score': 0.006512219086289406},
#   {'label': 'anger', 'score': 0.0048213223926723},
#   {'label': 'fear', 'score': 0.0035290238447487354}],
#  [{'label': 'neutral', 'score': 0.5494773387908936},
#   {'label': 'sadness', 'score': 0.11169011145830154},
#   {'label': 'disgust', 'score': 0.1040065661072731},
#   {'label': 'surprise', 'score': 0.07876542955636978},
#   {'label': 'anger', 'score': 0.06413352489471436},
#   {'label': 'fear', 'score': 0.05136272683739662},
#   {'label': 'joy', 'score': 0.040564339607954025}]]

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156353771686554},
#  {'label': 'disgust', 'score': 0.0026284793857485056},
#  {'label': 'fear', 'score': 0.06816215068101883},
#  {'label': 'joy', 'score': 0.0479423962533474},
#  {'label': 'neutral', 'score': 0.14038625359535217},
#  {'label': 'sadness', 'score': 0.0021221640054136515},
#  {'label': 'surprise', 'score': 0.7296021580696106}]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [0.06413352489471436,
#   0.6126183867454529,
#   0.06413352489471436,
#   0.35148337483406067,
#   0.08141220360994339,
#   0.23222479224205017,
#   0.5381850600242615,
#   0.06413352489471436,
#   0.3006710410118103,
#   0.06413352489471436],
#  'disgust': [0.2735902965068817,
#   0.34828585386276245,
#   0.1040065661072731,
#   0.15072239935398102,
#   0.1844952553510666,
#   0.7271748781204224,
#   0.15585508942604065,
#   0.1040065661072731,
#   0.279480904340744,
#   0.177926704287529],
#  'fear': [0.9281686544418335,
#   0.9425276517868042,
#   0.9723208546638489,
#   0.3607071340084076,
#   0.09504334628582001,
#   0.05136272683739662,
#   0.7474281787872314,
#   0.404495507478714,
#   0.9155241250991821,
#   0.05136272683739662],
#  'joy': [0.9327981472015381,
#   0.7044215202331543,
#   0.7672381401062012,
#   0.25188106298446655,
#   0.040564339607954025,
#   0.0433758944272995,
#   0.8725652098655701,
#   0.040564339607954025,
#   0.040564339607954025,
#   0.040564339607954025],
#  'sadness': [0.6462160348892212,
#   0.8879395127296448,
#   0.5494773387908936,
#   0.7326865792274475,
#   0.884389340877533,
#   0.6213927865028381,
#   0.712194561958313,
#   0.5494773387908936,
#   0.840289294719696,
#   0.8603722453117371],
#  'surprise': [0.9671575427055359,
#   0.11169011145830154,
#   0.11169011145830154,
#   0.11169011145830154,
#   0.4758807122707367,
#   0.11169011145830154,
#   0.4079986810684204,
#   0.8202826976776123,
#   0.35445940494537354,
#   0.11169011145830154],
#  'neutral': [0.7296021580696106,
#   0.25254449248313904,
#   0.07876542955636978,
#   0.07876542955636978,
#   0.07876542955636978,
#   0.27190259099006653,
#   0.07876542955636978,
#   0.23448799550533295,
#   0.1356150507926941,
#   0.07876542955636978]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|███████████████████████████████████████| 5197/5197 [06:44<00:00, 12.86it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
books = pd.merge(books, emotions_df, on = "isbn13")

# %%
books.to_csv("books_with_emotions.csv", index = False)

# %%
import gradio as gr


books = pd.read_csv("books_with_emotions.csv")
books["large_thumbnail"] = books["thumbnail"] + "&fife=w800"
books["large_thumbnail"] = np.where(
    books["large_thumbnail"].isna(),
    "cover-not-found.jpg",
    books["large_thumbnail"],
)

raw_documents = TextLoader("tagged_description.txt").load()
text_splitter = CharacterTextSplitter(separator="\n", chunk_size=2000, chunk_overlap=0)
documents = text_splitter.split_documents(raw_documents)

db_books = Chroma.from_documents(documents, embeddings)


def retrieve_semantic_recommendations(
        query: str,
        category: str = None,
        tone: str = None,
        initial_top_k: int = 50,
        final_top_k: int = 16,
) -> pd.DataFrame:

    recs = db_books.similarity_search(query, k=initial_top_k)
    books_list = [int(rec.page_content.strip('"').split()[0]) for rec in recs]
    book_recs = books[books["isbn13"].isin(books_list)].head(initial_top_k)

    if category != "All":
        book_recs = book_recs[book_recs["simple_categories"] == category].head(final_top_k)
    else:
        book_recs = book_recs.head(final_top_k)

    if tone == "Happy":
        book_recs.sort_values(by="joy", ascending=False, inplace=True)
    elif tone == "Surprising":
        book_recs.sort_values(by="surprise", ascending=False, inplace=True)
    elif tone == "Angry":
        book_recs.sort_values(by="anger", ascending=False, inplace=True)
    elif tone == "Suspenseful":
        book_recs.sort_values(by="fear", ascending=False, inplace=True)
    elif tone == "Sad":
        book_recs.sort_values(by="sadness", ascending=False, inplace=True)

    return book_recs


def recommend_books(
        query: str,
        category: str,
        tone: str
):
    recommendations = retrieve_semantic_recommendations(query, category, tone)
    results = []

    for _, row in recommendations.iterrows():
        description = row["description"]
        truncated_desc_split = description.split()
        truncated_description = " ".join(truncated_desc_split[:30]) + "..."
        authors_value = str(row["authors"]) if not pd.isna(row["authors"]) else "Unknown"

        authors_split = row["authors"].split(";")
        if len(authors_split) == 2:
            authors_str = f"{authors_split[0]} and {authors_split[1]}"
        elif len(authors_split) > 2:
            authors_str = f"{', '.join(authors_split[:-1])}, and {authors_split[-1]}"
        else:
            authors_str = row["authors"]

        caption = f"{row['title']} by {authors_str}: {truncated_description}"
        results.append((row["large_thumbnail"], caption))
    return results

categories = ["All"] + sorted(books["simple_categories"].unique())
tones = ["All"] + ["Happy", "Surprising", "Angry", "Suspenseful", "Sad"]

with gr.Blocks(theme = gr.themes.Glass()) as dashboard:
    gr.Markdown("# Semantic book recommender")

    with gr.Row():
        user_query = gr.Textbox(label = "Please enter a description of a book:",
                                placeholder = "e.g., A story about forgiveness")
        category_dropdown = gr.Dropdown(choices = categories, label = "Select a category:", value = "All")
        tone_dropdown = gr.Dropdown(choices = tones, label = "Select an emotional tone:", value = "All")
        submit_button = gr.Button("Find recommendations")

    gr.Markdown("## Recommendations")
    output = gr.Gallery(label = "Recommended books", columns = 8, rows = 2)

    submit_button.click(fn = recommend_books,
                        inputs = [user_query, category_dropdown, tone_dropdown],
                        outputs = output)


if __name__ == "__main__":
    dashboard.launch()
# Out:
# Created a chunk of size 2010, which is longer than the specified 2000
# Created a chunk of size 2012, which is longer than the specified 2000
# Created a chunk of size 2834, which is longer than the specified 2000
# Created a chunk of size 2510, which is longer than the specified 2000
# Created a chunk of size 2008, which is longer than the specified 2000
# Created a chunk of size 2285, which is longer than the specified 2000
# Created a chunk of size 2616, which is longer than the specified 2000
# Created a chunk of size 2030, which is longer than the specified 2000
# Created a chunk of size 2762, which is longer than the specified 2000
# Created a chunk of size 2005, which is longer than the specified 2000
# Created a chunk of size 2141, which is longer than the specified 2000
# Created a chunk of size 2209, which is longer than the specified 2000
# Created a chunk of size 2877, which is longer than the specified 2000
# Created a chunk of size 2398, which is longer than the specified 2000
# Created a chunk of size 2120, which is longer than the specified 2000
# Created a chunk of size 2181, which is longer than the specified 2000
# Created a chunk of size 2171, which is longer than the specified 2000
# Created a chunk of size 2723, which is longer than the specified 2000
# Created a chunk of size 2456, which is longer than the specified 2000
# Created a chunk of size 2450, which is longer than the specified 2000
# Created a chunk of size 3168, which is longer than the specified 2000
# Created a chunk of size 2034, which is longer than the specified 2000
# Created a chunk of size 2031, which is longer than the specified 2000
# Created a chunk of size 2940, which is longer than the specified 2000
# Created a chunk of size 2146, which is longer than the specified 2000
# Created a chunk of size 2490, which is longer than the specified 2000
# Created a chunk of size 3784, which is longer than the specified 2000
# Created a chunk of size 2702, which is longer than the specified 2000
# Created a chunk of size 5836, which is longer than the specified 2000
# Created a chunk of size 2075, which is longer than the specified 2000
# Created a chunk of size 2002, which is longer than the specified 2000
# Created a chunk of size 2082, which is longer than the specified 2000
# Created a chunk of size 2297, which is longer than the specified 2000
# Created a chunk of size 2071, which is longer than the specified 2000
# Created a chunk of size 2021, which is longer than the specified 2000
# Created a chunk of size 2022, which is longer than the specified 2000
# Created a chunk of size 2372, which is longer than the specified 2000
# Created a chunk of size 2351, which is longer than the specified 2000
# Created a chunk of size 2350, which is longer than the specified 2000
# Created a chunk of size 2334, which is longer than the specified 2000
# Created a chunk of size 2946, which is longer than the specified 2000
# Created a chunk of size 3243, which is longer than the specified 2000
# Created a chunk of size 2780, which is longer than the specified 2000
# Created a chunk of size 2085, which is longer than the specified 2000
# Created a chunk of size 2018, which is longer than the specified 2000
# Created a chunk of size 2713, which is longer than the specified 2000
# Created a chunk of size 2278, which is longer than the specified 2000
# Created a chunk of size 2051, which is longer than the specified 2000
# Created a chunk of size 2014, which is longer than the specified 2000
# Created a chunk of size 2067, which is longer than the specified 2000
# Created a chunk of size 2855, which is longer than the specified 2000
# Created a chunk of size 2869, which is longer than the specified 2000
# Created a chunk of size 2347, which is longer than the specified 2000
# Created a chunk of size 2451, which is longer than the specified 2000
# Created a chunk of size 2149, which is longer than the specified 2000
# Created a chunk of size 2742, which is longer than the specified 2000
# Created a chunk of size 3938, which is longer than the specified 2000
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
